# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df.diagnosis.value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
df.diagnosis.value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Diagnosis Distribution')  # Add a title
plt.ylabel('')  # Remove the default ylabel
plt.show()

# %%
df['Unnamed: 32'].unique()
# Out:
# array([nan])

# %%
# Select the first 10 features
features = df.columns[2:12]

# Create the boxplots
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features):
    plt.subplot(3, 4, i + 1)
    sns.boxplot(x='diagnosis', y=feature, data=df)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
# Create the heatmap
plt.figure(figsize=(12, 10))  # Adjust figure size as needed
sns.heatmap(df[features].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
# Select the next 10 features (features 12 to 21)
next_features = df.columns[12:22]

# Create the boxplots for the next 10 features
plt.figure(figsize=(15, 10))
for i, feature in enumerate(next_features):
    plt.subplot(3, 4, i + 1)  # Adjust subplot arrangement if needed
    sns.boxplot(x='diagnosis', y=feature, data=df)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
# Create the heatmap for the next 10 features
plt.figure(figsize=(12, 10))  # Adjust figure size as needed
sns.heatmap(df[next_features].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Next 10 Features')
plt.show()

# %%
# prompt: diagnostic distribution vs radius mean

# Plotting the distribution of radius_mean for different diagnosis
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='radius_mean', hue='diagnosis', kde=True)
plt.title('Distribution of Radius Mean by Diagnosis')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.show()

# %%
# Select the features for the pairplot
features_for_pairplot = ['concavity_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'diagnosis']

# Create the pairplot
sns.pairplot(df[features_for_pairplot], hue='diagnosis')
plt.show()

# %%
# Plotting the distribution of other features for different diagnosis
features_to_plot = ['texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']

for feature in features_to_plot:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=feature, hue='diagnosis', kde=True)
    plt.title(f'Distribution of {feature} by Diagnosis')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# Define features (X) and target (y)
X = df.drop(['diagnosis', 'Unnamed: 32', 'id'], axis=1)  # Exclude non-feature columns
y = df['diagnosis']

# Initialize and train a RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=100) # Set random_state for reproducibility
rf_classifier.fit(X, y)

# Get feature importances
feature_importances = rf_classifier.feature_importances_

# Create a DataFrame to store feature names and their importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print or visualize the feature importances
print(feature_importance_df)



plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance (Random Forest)')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
#                     Feature  Importance
# 23               area_worst    0.136583
# 22          perimeter_worst    0.131604
# 27     concave points_worst    0.114830
# 20             radius_worst    0.096151
# 7       concave points_mean    0.090215
# 2            perimeter_mean    0.062894
# 0               radius_mean    0.059007
# 3                 area_mean    0.051087
# 6            concavity_mean    0.047736
# 26          concavity_worst    0.030237
# 13                  area_se    0.028239
# 21            texture_worst    0.017514
# 1              texture_mean    0.016941
# 24         smoothness_worst    0.013990
# 5          compactness_mean    0.011518
# 10                radius_se    0.011057
# 28           symmetry_worst    0.010405
# 25        compactness_worst    0.010111
# 12             perimeter_se    0.009204
# 16             concavity_se    0.007179
# 4           smoothness_mean    0.005809
# 17        concave points_se    0.005125
# ...

# %%
# Assuming 'df' is your DataFrame as defined in the previous code

plt.figure(figsize=(10, 6))
sns.barplot(x='area_worst', y='diagnosis', data=df)
plt.title('Line Plot of Worst Area vs. Diagnosis')
plt.xlabel('Worst Area')
plt.ylabel('Diagnosis')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,f1_score,fbeta_score,confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.neighbors import RadiusNeighborsClassifier

# %%
##independent and dependent features
X = df.drop(['diagnosis', 'Unnamed: 32', 'id'], axis=1)
Y = df['diagnosis']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.30, random_state=42)

# %%
treemodel=RandomForestClassifier()
treemodel.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
f1score=f1_score(Y_test,treemodel.predict(X_test),average='weighted')
f1score
classificationsreport=classification_report(Y_test,treemodel.predict(X_test))
print(classificationsreport)
fbeta=fbeta_score(Y_test,treemodel.predict(X_test),average='weighted',beta=0.5)
fbeta
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       108
#            M       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171
# 0.9708219105663427

# %%
svm=svm.SVC()
svm.fit(X_train,Y_train)
# Out:
# SVC()

# %%
f1score=f1_score(Y_test,svm.predict(X_test),average='weighted')
f1score
classificationsreport=classification_report(Y_test,svm.predict(X_test))
print(classificationsreport)
fbeta=fbeta_score(Y_test,svm.predict(X_test),average='weighted',beta=0.5)
fbeta
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      1.00      0.95       108
#            M       1.00      0.83      0.90        63
#
#     accuracy                           0.94       171
#    macro avg       0.95      0.91      0.93       171
# weighted avg       0.94      0.94      0.93       171
# 0.9374609247173942

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
radiusclassifier=RadiusNeighborsClassifier(radius=10)
radiusclassifier.fit(X_train,Y_train)
# Out:
# RadiusNeighborsClassifier(radius=10)

# %%
confusion_matrix(Y_test, radiusclassifier.predict(X_test))
f1score=f1_score(Y_test,radiusclassifier.predict(X_test),average='weighted')
f1score
classificationsreport=classification_report(Y_test,radiusclassifier.predict(X_test))
print(classificationsreport)
fbeta=fbeta_score(Y_test,radiusclassifier.predict(X_test),average='weighted',beta=0.5)
fbeta
# Out:
#               precision    recall  f1-score   support
#
#            B       0.70      1.00      0.82       108
#            M       1.00      0.27      0.42        63
#
#     accuracy                           0.73       171
#    macro avg       0.85      0.63      0.62       171
# weighted avg       0.81      0.73      0.68       171
# 0.7101189987325447

# %%
model_accuracies = {
    'Random Forest': 0.97,
    'SVM': 0.93,
    'Radius Neighbors': 0.71
}

# Create a bar plot
plt.figure(figsize=(8, 6))
models = list(model_accuracies.keys())
accuracies = list(model_accuracies.values())
plt.bar(models, accuracies, color=['skyblue', 'salmon', 'lightgreen'])
plt.xlabel("Models")
plt.ylabel("Accuracy Score")
plt.title("Model Comparison")
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, f"{v:.2f}", ha='center')

plt.show()
